# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
import os

os.chdir('../will_horne_solo_project')
import local_functions as lf
os.chdir('../notebooks')

ec_init_a, ec_zero_a, ec_name_a = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/E-coli_901_1.xlsx",0.1)
ec_init_b, ec_zero_b, ec_name_b = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/E-coli_901_2.xlsx",0.1)

ec_init_total = ec_init_a.append(ec_init_b)
ec_zero_total = ec_zero_a.append(ec_zero_b)

lf.gen_plots(ec_init_total, ec_zero_total, ec_name_a)

# %%
values_to_drop_a = [('Aq', 'RT', 5), ('Aq', -80, 7), ('De', -80, 8)]
values_to_drop_b = [('D14-De', -80, 10), ('D28-De', 'RT', 2.5), ('D28-De', -80, 7.5)]

ec_init_a_edit, ec_zero_a_edit, ec_name_a = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/E-coli_901_1.xlsx",
                                                                  0.1,
                                                                  remove_values=True,
                                                                  removal_list=values_to_drop_a)
ec_init_b_edit, ec_zero_b_edit, ec_name_b = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/E-coli_901_2.xlsx",
                                                                  0.1,
                                                                  remove_values=True,
                                                                  removal_list=values_to_drop_b)

ec_init_total_edit = ec_init_a_edit.append(ec_init_b_edit)
ec_zero_total_edit = ec_zero_a_edit.append(ec_zero_b_edit)

lf.gen_plots(ec_init_total_edit, ec_zero_total_edit, ec_name_a, edited_data=True)

# %%
ab_init, ab_zero, ab_name = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/A-baumannii_AB5075.xlsx",0.005)

lf.gen_plots(ab_init, ab_zero, ab_name)

# %%
values_to_drop = [('Aq', -80, 3),
                  ('De', 'RT', 8),
                  ('De', -80, 8),
                  ('D28-De', 'RT', 7),
                  ('D28-De', -80, 7),
                  ('D28-De', 'RT', 8),
                  ('D28-De', -80, 8)]

ab_init_edit, ab_zero_edit, ab_name = lf.analyze_cfu_counts("../will_horne_solo_project/IR_Datasets/A-baumannii_AB5075.xlsx",
                                                            0.005,
                                                            remove_values=True,
                                                            removal_list=values_to_drop)

lf.gen_plots(ab_init_edit, ab_zero_edit, ab_name)
