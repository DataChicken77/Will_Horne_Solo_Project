# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
import os

os.chdir('../will_horne_solo_project')
import extract as extr
import clean as cln
import display as disp
import process as proc
os.chdir('../notebooks')

data_file = "../IR_Datasets/A-baumannii_AB5075.xlsx"
ab_init, ab_zero, ab_name = extr.analyze_cfu_counts(data_file,0.005)

disp.gen_plots(ab_init, ab_zero, ab_name)

# %%
values_to_drop = [('Aq', -80, 3),
                  ('De', 'RT', 8),
                  ('De', -80, 8),
                  ('D28-De', 'RT', 7),
                  ('D28-De', -80, 7),
                  ('D28-De', 'RT', 8),
                  ('D28-De', -80, 8)]

data_file = "../IR_Datasets/A-baumannii_AB5075.xlsx"
ab_init_edit, ab_zero_edit, ab_name = extr.analyze_cfu_counts(data_file,
                                                            0.005,
                                                            remove_values=True,
                                                            removal_list=values_to_drop)

disp.gen_plots(ab_init_edit, ab_zero_edit, ab_name, edited_data=True)

# %%
data_file = "../IR_Datasets/S-cerevisiae_EXF-6761.xlsx"
sc6761_init, sc6761_zero, sc6761_name = extr.analyze_cfu_counts(data_file,0.1)

disp.gen_plots(sc6761_init, sc6761_zero, sc6761_name)

# %%
values_to_drop = [('Aq', 'RT', 10),
                  ('Aq', -80, 18),
                  ('D28-De', 'RT', 18),
                  ('D28-De', -80, 21)]

data_file = "../IR_Datasets/S-cerevisiae_EXF-6761.xlsx"
sc6761_init_edit, sc6761_zero_edit, sc6761_name = extr.analyze_cfu_counts(data_file,
                                                              0.1,
                                                              remove_values=True,
                                                              removal_list=values_to_drop)

disp.gen_plots(sc6761_init_edit, sc6761_zero_edit, sc6761_name, edited_data=True)
